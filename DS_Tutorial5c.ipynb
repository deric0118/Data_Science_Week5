# %% [markdown]
# <a href="https://colab.research.google.com/github/deric0118/Data_Science_Week5/blob/main/DS_Tutorial5c.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Source - http://stackoverflow.com/a
# Posted by tanemaki, modified by community. See post 'Timeline' for change history
# Retrieved 2025-11-12, License - CC BY-SA 4.0

import pandas as pd
import numpy as np
from scipy import stats

df = pd.DataFrame(np.random.randn(100, 3))

df[(np.abs(stats.zscore(df)) < 3).all(axis=1)] # Many standard deviations a data point is from the mean of its dataset.Z-score

print(df)
# Out:
#            0         1         2
# 0  -1.451517  1.325705  0.380020
# 1   0.577692 -0.598244  0.689837
# 2   0.689560  0.107935 -0.044174
# 3   0.286023  0.581691  0.158420
# 4   0.498129 -1.535048  0.102665
# ..       ...       ...       ...
# 95  0.635367 -1.677032 -0.181250
# 96  0.078799 -0.842597  0.166107
# 97  0.212057  1.372128 -0.134097
# 98 -0.097155 -0.102284 -0.105669
# 99  1.071425  1.641215  0.532306
#
# [100 rows x 3 columns]

# %%
# Step 1: Create a simple dataframe with obvious outliers
data = {
    'Score': [85, 90, 78, 92, 88, 200, 85, 89, -50, 87]
}
df = pd.DataFrame(data)

print("ORIGINAL DATA: ")
print(df)

# Step 2: Romove outliers using Z-score method
df_clean = df[(np.abs(stats.zscore(df)) < 2).all(axis=1)]

print("\nCLEANED DATA (outliers removed): ")
print(df_clean)

# Step 3: Show what happened
print(f"\nSUMMARY: ")
print(f"Original rows: {len(df)}")
print(f"Rows after cleaning: {len(df_clean)}")
print(f"Outliers removed: {len(df) - len(df_clean)}")
# Out:
# ORIGINAL DATA:
#    Score
# 0     85
# 1     90
# 2     78
# 3     92
# 4     88
# 5    200
# 6     85
# 7     89
# 8    -50
# 9     87
#
# CLEANED DATA (outliers removed):
#    Score
# 0     85
# 1     90
# 2     78
# 3     92
# 4     88
# 6     85
# 7     89
# 9     87
#
# SUMMARY:
# Original rows: 10
# Rows after cleaning: 8
# Outliers removed: 2
